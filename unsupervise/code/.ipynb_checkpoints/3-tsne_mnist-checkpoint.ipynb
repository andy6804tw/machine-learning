# %%
import numpy as np
np.set_printoptions(precision=2)
np.set_printoptions(suppress=True)
from pprint import pprint
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# %matplotlib inline

# %% [markdown]
# ### 載入digits資料集

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
y = digits.target

# %% [markdown]
# ### 使用t-SNE做降維，sklearn t-SNE中較重要的參數:
# - n_components: 降維之後的維度
# - perpexity: 最佳化過程中考慮鄰近點的多寡，default 30，原始paper建議5-50
# - n_iter: 迭代次數，預設1000

# %%
tsne = TSNE(n_components=2, random_state=42,n_iter=5000)
X_reduced = tsne.fit_transform(X)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, alpha=0.5,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))

plt.colorbar()
plt.show()

# %% [markdown]
# ## XGboost learn model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, X_reduced, test_size = 0.3, random_state=100)

# %%
import xgboost as xgb
from sklearn.multioutput import MultiOutputRegressor
# fitting
multioutputregressor = MultiOutputRegressor(xgb.XGBRegressor(objective='reg:linear')).fit(X_train, y_train)
# Out:
# /Users/yilin/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:613: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn("Use subset (sliced data) of np.ndarray is not recommended " +
# [10:59:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:59:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
regr = MultiOutputRegressor(knn)
 
regr.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=KNeighborsRegressor(algorithm='auto',
#                                                    leaf_size=30,
#                                                    metric='minkowski',
#                                                    metric_params=None,
#                                                    n_jobs=None, n_neighbors=5,
#                                                    p=2, weights='uniform'),
#                      n_jobs=None)

# %%
# predicting
# pred=multioutputregressor.predict(X_test)
pred=regr.predict(X_test)

# %%
print(y_test)
# Out:
# [[ 30.43  -0.01]
#  [ 39.03   6.64]
#  [103.8   -8.73]
#  ...
#  [ 12.19  79.12]
#  [ -8.58  23.37]
#  [-66.96  25.37]]

# %%
plt.figure(figsize=(8,6))
plt.scatter(pred[:, 0], pred[:, 1], alpha=0.5,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))

plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test[:, 0], y_test[:, 1], alpha=0.5,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))

plt.colorbar()
plt.show()
